# %%
import torch
from torchvision import datasets
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %% [markdown]
# ### Loading the dataset

# %%
train_data = datasets.MNIST(root='./data', train=True, download=True)
test_data = datasets.MNIST(root='./data', train=False, download=True)

# %% [markdown]
# ### Visualising few of the digits

# %%
plt.figure(figsize=(4, 4))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(train_data.data[i], cmap='gray')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Coding the MLP - one layer at a time

# %% [markdown]
# Layer 1
# Relu

# %%
w1 = torch.rand((256, 784))
x1 = train_data.data.float().reshape(-1, 784, 1)
print(w1.shape)
print(x1.shape)
# Out:
# torch.Size([256, 784])
# torch.Size([60000, 784, 1])

# %%
# Out:
# torch.Size([784, 1])

# %%
w1_1x1_1 = w1_1 @ x1_1
F.relu(w1_1x1_1[0][0])
# Out:
# tensor(13708.7295)
